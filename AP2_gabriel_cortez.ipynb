# %% [markdown]
# # AP2 - Predicao de Genero em Reviews
#
# **Aluno:** Gabriel Cortez
#
# **Data:** 17/05/2026

# %% [markdown]
# ## 1. Preparar ambiente e importar bibliotecas
#
# Nesta etapa, importamos bibliotecas essenciais e ajustamos configuracoes basicas.

# %%
import warnings

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# Configuracoes basicas
pd.set_option("display.max_colwidth", 200)
pd.set_option("display.max_columns", 50)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Carregar e inspecionar dados
#
# Carregamos os arquivos e fazemos uma inspecao inicial (shape, tipos, valores faltantes).

# %%
# Ajuste os caminhos se necessario
train_path = "treino.csv"
val_path = "validacao.csv"

train_df = pd.read_csv(train_path)
val_df = pd.read_csv(val_path)

# Visao geral
print("Treino:", train_df.shape)
print("Validacao:", val_df.shape)

print("\nColunas:")
print(train_df.columns)

print("\nTipos:")
print(train_df.dtypes)

print("\nValores faltantes (treino):")
print(train_df.isna().sum().sort_values(ascending=False).head(10))

print("\nDistribuicao de genero (treino):")
print(train_df["reviewer_gender"].value_counts(dropna=False))

# Amostras
train_df.head(5)
